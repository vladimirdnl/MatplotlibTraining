# %%
# %matplotlib notebook
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %%
slices = [55631, 12039]
labels = ['Sixty', 'Forty']

# %%
plt.pie(slices, labels = labels, wedgeprops = {'edgecolor' : 'black'}, autopct = '%1.1f%%')
# Out:
# <img src="data:image/png;base64,..." width="670.4762209245691">
# ([<matplotlib.patches.Wedge at 0x1f29cda70b8>,
#   <matplotlib.patches.Wedge at 0x1f29d0cb4e0>],
#  [Text(-0.9326153326374192, 0.5832912148572066, 'Sixty'),
#   Text(0.9326153872490797, -0.5832911275394554, 'Forty')],
#  [Text(-0.5086992723476832, 0.3181588444675672, '82.2%'),
#   Text(0.5086993021358616, -0.31815879683970294, '17.8%')])
